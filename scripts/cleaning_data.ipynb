# %%
import pandas as pd
import numpy as np

# %%
path = "../canada_fsa_climate_footprint.csv"

df = pd.read_csv(path, header=2, thousands=",")

df.head(5)
# Out:
#    FSA                                Name / Area       Province / Territory  \
# 0  A0A  Southeastern Avalon Peninsula (Ferryland)  Newfoundland and Labrador
# 1  A0B        Western Avalon Peninsula (Argentia)  Newfoundland and Labrador
# 2  A0C            Bonavista Peninsula (Bonavista)  Newfoundland and Labrador
# 3  A0E                Burin Peninsula (Marystown)  Newfoundland and Labrador
# 4  A0G        Northeast Newfoundland (Lewisporte)  Newfoundland and Labrador
#
#        Lat      Lon Nearest Major Airport Airport IATA  Airport SL km  \
# 0  47.2195 -53.1448       St. John's Intl          YYT           53.3
# 1  47.3270 -53.6609       St. John's Intl          YYT           75.6
# 2  48.3843 -53.9081       St. John's Intl          YYT          121.0
# 3  47.5607 -54.7801       St. John's Intl          YYT          152.2
# 4  48.8657 -54.7296       St. John's Intl          YYT          201.7
#
#    Dist Set A km\n(YVR+SFO)  Dist Set B km\n(YYZ+JFK)  ...          D2 Name  \
# 0                    5298.4                    1946.1  ...    Gros Morne NL
# 1                    5258.2                    1909.9  ...    Gros Morne NL
# 2                    5197.7                    1915.2  ...    Gros Morne NL
# 3                    5171.1                    1832.8  ...    Gros Morne NL
# 4                    5122.8                    1870.7  ...  Corner Brook NL
#
#   D2 SL km  D2 Driving km  D2 Driving hrs  CO2e CDG kg CO2e LHR kg  \
# 0    432.0         711.31         10.1441        745.8       811.6
# 1    394.6         633.14          8.0713        745.8       811.6
# 2    312.7         512.28          6.7709        745.8       811.6
# 3    315.9         661.48          8.8154        745.8       811.6
# 4    235.6         463.40          7.5179        745.8       811.6
#
#    CO2e NRT kg  Set Airport 1\n(IATA)  CO2e Set1 kg  CO2e Set2 kg
# 0       1878.9                    YVR        1097.5        1241.7
# 1       1878.9                    YVR        1097.5        1241.7
# 2       1878.9                    YVR        1097.5        1241.7
# 3       1878.9                    YVR        1097.5        1241.7
# 4       1878.9                    YVR        1097.5        1241.7
#
# [5 rows x 25 columns]

# %%
df.head()
# df = df.drop(columns=["Lat", "Lon"])
# df = df.drop(columns="Airport SL km")
# Out:
#    FSA                                Name / Area       Province / Territory  \
# 0  A0A  Southeastern Avalon Peninsula (Ferryland)  Newfoundland and Labrador
# 1  A0B        Western Avalon Peninsula (Argentia)  Newfoundland and Labrador
# 2  A0C            Bonavista Peninsula (Bonavista)  Newfoundland and Labrador
# 3  A0E                Burin Peninsula (Marystown)  Newfoundland and Labrador
# 4  A0G        Northeast Newfoundland (Lewisporte)  Newfoundland and Labrador
#
#   Nearest Major Airport Airport IATA  Dist Set A km\n(YVR+SFO)  \
# 0       St. John's Intl          YYT                    5298.4
# 1       St. John's Intl          YYT                    5258.2
# 2       St. John's Intl          YYT                    5197.7
# 3       St. John's Intl          YYT                    5171.1
# 4       St. John's Intl          YYT                    5122.8
#
#    Dist Set B km\n(YYZ+JFK) Further Set                       D1 Name  \
# 0                    1946.1           A                 St. John's NL
# 1                    1909.9           A                 St. John's NL
# 2                    1915.2           A                 St. John's NL
# 3                    1832.8           A  Cape Breton (Cabot Trail) NS
# 4                    1870.7           A                 St. John's NL
#
#    D1 SL km  ...          D2 Name  D2 SL km D2 Driving km  D2 Driving hrs  \
# 0      50.0  ...    Gros Morne NL     432.0        711.31         10.1441
# 1      75.9  ...    Gros Morne NL     394.6        633.14          8.0713
# 2     127.6  ...    Gros Morne NL     312.7        512.28          6.7709
# 3     471.5  ...    Gros Morne NL     315.9        661.48          8.8154
# 4     208.2  ...  Corner Brook NL     235.6        463.40          7.5179
#
#    CO2e CDG kg  CO2e LHR kg  CO2e NRT kg  Set Airport 1\n(IATA)  CO2e Set1 kg  \
# 0        745.8        811.6       1878.9                    YVR        1097.5
# 1        745.8        811.6       1878.9                    YVR        1097.5
# 2        745.8        811.6       1878.9                    YVR        1097.5
# 3        745.8        811.6       1878.9                    YVR        1097.5
# 4        745.8        811.6       1878.9                    YVR        1097.5
#
#   CO2e Set2 kg
# 0       1241.7
# 1       1241.7
# 2       1241.7
# 3       1241.7
# 4       1241.7
#
# [5 rows x 22 columns]
