# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'A': [np.nan, 1, 2], 'B': ["hello", 'world', None]})

# %%
df.isna()
if df.empty() : df_1 = df.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 df.isna()
# ----> 2 if df.empty() : df_1 = df.fillna(0)
#
# TypeError: 'bool' object is not callable
